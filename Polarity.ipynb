# %%
import nltk

# %%
from textblob import TextBlob

# %%
import numpy as np
import random
import string

# %%
from wordcloud import WordCloud

# %%
import pandas as pd
from collections import Counter

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\hjeet\\Downloads\\fake reviews\\fake_review.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 polarity_class  \
# 0           0        negtive
# 1           1        negtive
# 2           2        negtive
# 3           3        negtive
# 4           4        negtive
#
#                                               review  spamity_class
# 0  We stayed at the Schicago Hilton for 4 days an...              0
# 1  Hotel is located 1/2 mile from the train stati...              0
# 2  I made my reservation at the Hilton Chicago be...              0
# 3  When most people think Hilton, they think luxu...              0
# 4  My husband and I recently stayed stayed at the...              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 4 columns):
# Unnamed: 0        1600 non-null int64
# polarity_class    1600 non-null object
# review            1600 non-null object
# spamity_class     1600 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 50.1+ KB

# %%
j=[]
for i in range(0,1599):
    j.append(data.review[i])

# %%
s=" ".join(j)

# %%
j=s.split()
j
# Out:
# ['We',
#  'stayed',
#  'at',
#  'the',
#  'Schicago',
#  'Hilton',
#  'for',
#  '4',
#  'days',
#  'and',
#  '3',
#  'nights',
#  'for',
#  'a',
#  'conference.',
#  'I',
#  'have',
#  'to',
#  'say,',
#  'normally',
#  'I',
#  'am',
#  'very',
#  'easy',
#  'going',
#  'about',
#  'amenities,',
#  'cleanliness,',
#  'and',
#  'the',
#  'like...however',
#  'our',
#  'experience',
#  'at',
#  'the',
#  'Hilton',
#  'was',
#  'so',
#  'awful',
#  'I',
#  'am',
#  'taking',
#  'the',
#  'time',
#  'to',
#  'actually',
#  'write',
#  'this',
#  'review.',
#  'Truly,',
#  'DO',
#  'NOT',
#  'stay',
#  'at',
#  'this',
#  'hotel.',
#  'When',
#  'we',
#  'arrived',
#  'in',
#  'our',
#  'room,',
#  'it',
#  'was',
#  'clear',
#  'that',
#  'the',
#  'carpet',
#  "hadn't",
#  'been',
#  'vacuumed.',
#  'I',
#  'figuered,',
#  '"okay,',
#  "it's",
#  'just',
#  'the',
#  'carpet."',
#  'Until',
#  'I',
#  'saw',
#  'the',
#  'bathroom!',
#  'Although',
#  'the',
#  'bathroom',
#  'had',
# ...

# %%
# most common used words
count = Counter(j)
count.most_common(20)
# Out:
# [('the', 12771),
#  ('and', 7733),
#  ('to', 6667),
#  ('a', 6310),
#  ('I', 5941),
#  ('was', 5772),
#  ('in', 3587),
#  ('of', 3271),
#  ('The', 3131),
#  ('for', 2723),
#  ('at', 2239),
#  ('is', 2106),
#  ('hotel', 2060),
#  ('room', 2033),
#  ('we', 1998),
#  ('that', 1928),
#  ('my', 1816),
#  ('it', 1737),
#  ('were', 1719),
#  ('with', 1709)]

# %%
len(j)
# Out:
# 237953

# %%
p=['the','and','to','a','I','was','in','of','The','for','at', 'is','hotel','room','we','that','my','it','were','with']
q=[12771, 7733,6667,6310,5941, 5772,3587,3271,3131,2723,2239, 2106, 2060, 2033, 1998,1928,1816, 1737,1719, 1709]
plt.bar(p,q,color="green")
plt.title("Most Frequent Words")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.show()

# %%
from nltk.corpus import stopwords

# %%
word=stopwords.words("english")
word
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
# wordcloud without removing the stopwords

# %%
wordcloud = WordCloud(stopwords=word, background_color="black",max_words=1000,).generate(s)

# %%
plt.figure(figsize=[18,8])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from textblob import TextBlob

# %%
# download the file by running this block
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\hjeet\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True

# %%
from textblob import TextBlob
blob = TextBlob(s)
a=[]
a.append(blob.noun_phrases)
# It is used to find main noun in sentenes that are used to find the positive and negative essence in word

# %%
 # implementing word cloud after removing the stopwords in the text
wordcloud = WordCloud( background_color="white",max_words=1000 ).generate(s)

# %%
plt.figure(figsize=[18,8])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#how to find polarity

# %%
sentence=data.review[0]

# %%
sentence
# Out:
# 'We stayed at the Schicago Hilton for 4 days and 3 nights for a conference. I have to say, normally I am very easy going about amenities, cleanliness, and the like...however our experience at the Hilton was so awful I am taking the time to actually write this review. Truly, DO NOT stay at this hotel. When we arrived in our room, it was clear that the carpet hadn\'t been vacuumed. I figuered, "okay, it\'s just the carpet." Until I saw the bathroom! Although the bathroom had all the superficial indicators of housekeeping having recently cleaned (i.e., a paper band across the toilet, paper caps on the drinking glasses, etc., it was clear that no ACTUAL cleaning took place. There was a spot (probably urine!) on the toilet seat and, I kid you not, the remnants of a lip-smudge on the glass. I know people who have worked many years in the hotel industry and they always warned that lazy housekeeping will make things "appear" clean but in fact they make no effort to keep things sanitary. Well
# ...

# %%
sen=s.split()

# %%
sen
# Out:
# ['We',
#  'stayed',
#  'at',
#  'the',
#  'Schicago',
#  'Hilton',
#  'for',
#  '4',
#  'days',
#  'and',
#  '3',
#  'nights',
#  'for',
#  'a',
#  'conference.',
#  'I',
#  'have',
#  'to',
#  'say,',
#  'normally',
#  'I',
#  'am',
#  'very',
#  'easy',
#  'going',
#  'about',
#  'amenities,',
#  'cleanliness,',
#  'and',
#  'the',
#  'like...however',
#  'our',
#  'experience',
#  'at',
#  'the',
#  'Hilton',
#  'was',
#  'so',
#  'awful',
#  'I',
#  'am',
#  'taking',
#  'the',
#  'time',
#  'to',
#  'actually',
#  'write',
#  'this',
#  'review.',
#  'Truly,',
#  'DO',
#  'NOT',
#  'stay',
#  'at',
#  'this',
#  'hotel.',
#  'When',
#  'we',
#  'arrived',
#  'in',
#  'our',
#  'room,',
#  'it',
#  'was',
#  'clear',
#  'that',
#  'the',
#  'carpet',
#  "hadn't",
#  'been',
#  'vacuumed.',
#  'I',
#  'figuered,',
#  '"okay,',
#  "it's",
#  'just',
#  'the',
#  'carpet."',
#  'Until',
#  'I',
#  'saw',
#  'the',
#  'bathroom!',
#  'Although',
#  'the',
#  'bathroom',
#  'had',
# ...

# %%
# removing the stopwords from the sentence
w=[]
m=[]
for i in range(0,len(sen)):
    if(sen[i] not in word):
        w.append(sen[i])
    else:
        m.append(sen[i])

# %%
# words left after stopwords removal
w
# Out:
# ['We',
#  'stayed',
#  'Schicago',
#  'Hilton',
#  '4',
#  'days',
#  '3',
#  'nights',
#  'conference.',
#  'I',
#  'say,',
#  'normally',
#  'I',
#  'easy',
#  'going',
#  'amenities,',
#  'cleanliness,',
#  'like...however',
#  'experience',
#  'Hilton',
#  'awful',
#  'I',
#  'taking',
#  'time',
#  'actually',
#  'write',
#  'review.',
#  'Truly,',
#  'DO',
#  'NOT',
#  'stay',
#  'hotel.',
#  'When',
#  'arrived',
#  'room,',
#  'clear',
#  'carpet',
#  'vacuumed.',
#  'I',
#  'figuered,',
#  '"okay,',
#  'carpet."',
#  'Until',
#  'I',
#  'saw',
#  'bathroom!',
#  'Although',
#  'bathroom',
#  'superficial',
#  'indicators',
#  'housekeeping',
#  'recently',
#  'cleaned',
#  '(i.e.,',
#  'paper',
#  'band',
#  'across',
#  'toilet,',
#  'paper',
#  'caps',
#  'drinking',
#  'glasses,',
#  'etc.,',
#  'clear',
#  'ACTUAL',
#  'cleaning',
#  'took',
#  'place.',
#  'There',
#  'spot',
#  '(probably',
#  'urine!)',
#  'toilet',
#  'seat',
#  'and,',
#  'I',
#  'kid',
#  'not,',
# ...

# %%
# using stemmer to get root word of each word
PorterStemmer = nltk.stem.porter.PorterStemmer()

# %%
root=[]
for i in range(0,len(w)):
    root.append(PorterStemmer.stem(w[i]))
    
root
# Out:
# ['We',
#  'stay',
#  'schicago',
#  'hilton',
#  '4',
#  'day',
#  '3',
#  'night',
#  'conference.',
#  'I',
#  'say,',
#  'normal',
#  'I',
#  'easi',
#  'go',
#  'amenities,',
#  'cleanliness,',
#  'like...howev',
#  'experi',
#  'hilton',
#  'aw',
#  'I',
#  'take',
#  'time',
#  'actual',
#  'write',
#  'review.',
#  'truly,',
#  'DO',
#  'not',
#  'stay',
#  'hotel.',
#  'when',
#  'arriv',
#  'room,',
#  'clear',
#  'carpet',
#  'vacuumed.',
#  'I',
#  'figuered,',
#  '"okay,',
#  'carpet."',
#  'until',
#  'I',
#  'saw',
#  'bathroom!',
#  'although',
#  'bathroom',
#  'superfici',
#  'indic',
#  'housekeep',
#  'recent',
#  'clean',
#  '(i.e.,',
#  'paper',
#  'band',
#  'across',
#  'toilet,',
#  'paper',
#  'cap',
#  'drink',
#  'glasses,',
#  'etc.,',
#  'clear',
#  'actual',
#  'clean',
#  'took',
#  'place.',
#  'there',
#  'spot',
#  '(probabl',
#  'urine!)',
#  'toilet',
#  'seat',
#  'and,',
#  'I',
#  'kid',
#  'not,',
#  'remnant',
#  'lip-smudg',
#  'glass.',
# ...

# %%
mm=" ".join(root)

# %%
mm
# Out:
# 'We stay schicago hilton 4 day 3 night conference. I say, normal I easi go amenities, cleanliness, like...howev experi hilton aw I take time actual write review. truly, DO not stay hotel. when arriv room, clear carpet vacuumed. I figuered, "okay, carpet." until I saw bathroom! although bathroom superfici indic housekeep recent clean (i.e., paper band across toilet, paper cap drink glasses, etc., clear actual clean took place. there spot (probabl urine!) toilet seat and, I kid not, remnant lip-smudg glass. I know peopl work mani year hotel industri alway warn lazi housekeep make thing "appear" clean fact make effort keep thing sanitary. well, hilton proof. I call downstair complained, sent chambermaid hour later. frankly, I found room disgusting. the hotel itself, outsid rooms, cavern unwelcoming, aw echo lobbi area creat migraine-induc din. rare I eager leav place this. when I got home, I wash cloth whether I worn not, skeevi accomodations. please, favor stay clean hotel. hotel locat
# ...

# %%
# finding the polarity from sentence mm
TextBlob(mm).sentiment.polarity
# Out:
# 0.19244058693963118

# %%
#finding the subjectivity of mm means finding logical viewpoints
TextBlob(mm).sentiment.subjectivity
# Out:
# 0.5130648872928688
